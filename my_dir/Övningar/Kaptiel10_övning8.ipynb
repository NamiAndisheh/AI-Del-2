# %% [markdown]
# # Övning 8 Skapa en chattbott

# %%
import numpy as np
from google import genai
from pypdf import PdfReader

# %%
import os
api_key = api_key=os.getenv("API_KEY")

api_key = 'AIzaSyAZ_7tz9oaIOkn0Nd-jFVii6OuXhqPhQxk'
client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.0-flash", 
    contents="vem är zlatan"
)

print(response.text)
# Out:
# Zlatan Ibrahimović är en svensk före detta professionell fotbollsspelare som spelade som anfallare. Han är allmänt betraktad som en av de bästa anfallarna genom tiderna och en av de mest dekorerade fotbollsspelarna aktivt.
#
# Här är några viktiga punkter om honom:
#
# *   **Karriär:** Han har spelat för klubbar som Malmö FF, Ajax, Juventus, Inter Milan, Barcelona, AC Milan, Paris Saint-Germain, Manchester United och Los Angeles Galaxy. Han avslutade sin karriär i AC Milan 2023.
# *   **Landslag:** Han är Sveriges främste målskytt genom tiderna.
# *   **Stil:** Känd för sin teknik, styrka, målfarlighet och sin karismatiska personlighet.
# *   **Titlar:** Han har vunnit ligatitlar i Nederländerna, Italien, Frankrike och England.
# *   **Personlighet:** Han är känd för sina ofta kaxiga uttalanden och sin självsäkerhet.
